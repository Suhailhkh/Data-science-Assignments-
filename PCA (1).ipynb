# %%
# !pip
# Out:
# Usage:
#   pip <command> [options]
#
# Commands:
#   install                     Install packages.
#   download                    Download packages.
#   uninstall                   Uninstall packages.
#   freeze                      Output installed packages in requirements format.
#   inspect                     Inspect the python environment.
#   list                        List installed packages.
#   show                        Show information about installed packages.
#   check                       Verify installed packages have compatible dependencies.
#   config                      Manage local and global configuration.
#   search                      Search PyPI for packages.
#   cache                       Inspect and manage pip's wheel cache.
#   index                       Inspect information available from package indexes.
#   wheel                       Build wheels from your requirements.
#   hash                        Compute hashes of package archives.
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.decomposition import PCA
from sklearn import metrics
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering,KMeans,DBSCAN

import warnings
warnings.filterwarnings('ignore')

# %%
wine_info=pd.read_csv('wine.csv')
wine_info
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
wine_info.isnull().sum()
# Out:
# Type               0
# Alcohol            0
# Malic              0
# Ash                0
# Alcalinity         0
# Magnesium          0
# Phenols            0
# Flavanoids         0
# Nonflavanoids      0
# Proanthocyanins    0
# Color              0
# Hue                0
# Dilution           0
# Proline            0
# dtype: int64

# %%
wine_info.dtypes
# Out:
# Type                 int64
# Alcohol            float64
# Malic              float64
# Ash                float64
# Alcalinity         float64
# Magnesium            int64
# Phenols            float64
# Flavanoids         float64
# Nonflavanoids      float64
# Proanthocyanins    float64
# Color              float64
# Hue                float64
# Dilution           float64
# Proline              int64
# dtype: object

# %%
wine_info.shape
# Out:
# (178, 14)

# %%
wine_info.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# ...

# %%
sns.countplot(x=wine_info['Type'])
plt.show()

# %%
wine_info['Type'].value_counts()
# Out:
# 2    71
# 1    59
# 3    48
# Name: Type, dtype: int64

# %%
wine_info=wine_info.iloc[:,1:]
wine_info
# Out:
#      Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0      14.23   1.71  2.43        15.6        127     2.80        3.06
# 1      13.20   1.78  2.14        11.2        100     2.65        2.76
# 2      13.16   2.36  2.67        18.6        101     2.80        3.24
# 3      14.37   1.95  2.50        16.8        113     3.85        3.49
# 4      13.24   2.59  2.87        21.0        118     2.80        2.69
# ..       ...    ...   ...         ...        ...      ...         ...
# 173    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177    14.13   4.10  2.74        24.5         96     2.05        0.76
#
#      Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# ...

# %% [markdown]
# Scaling Data

# %%
scaled=MinMaxScaler()
scaled=scaled.fit_transform(wine_info)
wine_scaled=pd.DataFrame(data=scaled,columns=wine_info.columns)
wine_scaled
# Out:
#       Alcohol     Malic       Ash  Alcalinity  Magnesium   Phenols  \
# 0    0.842105  0.191700  0.572193    0.257732   0.619565  0.627586
# 1    0.571053  0.205534  0.417112    0.030928   0.326087  0.575862
# 2    0.560526  0.320158  0.700535    0.412371   0.336957  0.627586
# 3    0.878947  0.239130  0.609626    0.319588   0.467391  0.989655
# 4    0.581579  0.365613  0.807487    0.536082   0.521739  0.627586
# ..        ...       ...       ...         ...        ...       ...
# 173  0.705263  0.970356  0.582888    0.510309   0.271739  0.241379
# 174  0.623684  0.626482  0.598930    0.639175   0.347826  0.282759
# 175  0.589474  0.699605  0.481283    0.484536   0.543478  0.210345
# 176  0.563158  0.365613  0.540107    0.484536   0.543478  0.231034
# 177  0.815789  0.664032  0.737968    0.716495   0.282609  0.368966
#
#      Flavanoids  Nonflavanoids  Proanthocyanins     Color       Hue  Dilution  \
# 0      0.573840       0.283019         0.593060  0.372014  0.455285  0.970696
# ...

# %% [markdown]
# PCA

# %%
pca_decomposition=PCA(random_state=12)
wine_transformed=pca_decomposition.fit_transform(wine_scaled)
wine_transformed
# Out:
# array([[-0.70633576, -0.25319275,  0.02409269, ...,  0.04971144,
#         -0.02001158, -0.00872296],
#        [-0.4849768 , -0.00882289, -0.28048205, ...,  0.07415784,
#         -0.05083753, -0.00524944],
#        [-0.52117227, -0.18918722,  0.19621674, ...,  0.0121311 ,
#         -0.10418449, -0.02316441],
#        ...,
#        [ 0.62631289, -0.54685701, -0.03049476, ...,  0.13116697,
#          0.11160576,  0.0389133 ],
#        [ 0.5729911 , -0.42551609, -0.09453672, ...,  0.03027458,
#          0.05732893,  0.01103053],
#        [ 0.701764  , -0.51350498,  0.29390996, ..., -0.02784028,
#          0.01873501, -0.06648261]])

# %%
pca_explained_ratio=pca_decomposition.explained_variance_ratio_
pca_explained_ratio
# Out:
# array([0.40749485, 0.18970352, 0.08561671, 0.07426678, 0.05565301,
#        0.04658837, 0.03663929, 0.02408789, 0.02274371, 0.02250965,
#        0.01381292, 0.01273236, 0.00815095])

# %%
var=np.cumsum(np.round(a=pca_explained_ratio,decimals=4)*100)

# %%
plt.plot(var,color='green')
plt.show()

# %%
x=wine_transformed[:,0]
y=wine_transformed[:,1]
z=wine_transformed[:,2]
sns.scatterplot(x=x,y=y)
plt.show()

# %%
sns.scatterplot(x=y,y=z)
plt.show()

# %%
sns.scatterplot(x=x,y=z)
plt.show()

# %%
plt.figure(figsize=(6,5))
axes=plt.axes(projection='3d')
axes.scatter3D(x,y,z)
axes.set_xlabel('pc1',color='green')
axes.set_ylabel('pc2',color='red')
axes.set_zlabel('pc3' ,color='blue')
plt.show()

# %%
wine_data1 = pd.DataFrame(wine_transformed[0:,:3],columns=['pc1','pc2','pc3'])
wine_data1
# Out:
#           pc1       pc2       pc3
# 0   -0.706336 -0.253193  0.024093
# 1   -0.484977 -0.008823 -0.280482
# 2   -0.521172 -0.189187  0.196217
# 3   -0.821644 -0.580906  0.081110
# 4   -0.202546 -0.059467  0.300240
# ..        ...       ...       ...
# 173  0.739510 -0.471901  0.209360
# 174  0.581781 -0.348366  0.083590
# 175  0.626313 -0.546857 -0.030495
# 176  0.572991 -0.425516 -0.094537
# 177  0.701764 -0.513505  0.293910
#
# [178 rows x 3 columns]

# %% [markdown]
# Clustering

# %%
dendrogram=sch.dendrogram(sch.linkage(wine_transformed,method='complete'))

# %%
hc=AgglomerativeClustering(n_clusters=3,linkage='ward')
hc_cluster=hc.fit_predict(wine_transformed)
hc_cluster_df=pd.DataFrame(hc_cluster,columns=['Clusters'])
hc_cluster_df
# Out:
#      Clusters
# 0           2
# 1           2
# 2           2
# 3           2
# 4           0
# ..        ...
# 173         1
# 174         1
# 175         1
# 176         1
# 177         1
#
# [178 rows x 1 columns]

# %%
hc_cluster_df.value_counts()
# Out:
# Clusters
# 0           71
# 2           57
# 1           50
# dtype: int64

# %%
wine1=wine_info.copy()
wine1['hc_cluster']=hc_cluster_df
wine1
# Out:
#      Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0      14.23   1.71  2.43        15.6        127     2.80        3.06
# 1      13.20   1.78  2.14        11.2        100     2.65        2.76
# 2      13.16   2.36  2.67        18.6        101     2.80        3.24
# 3      14.37   1.95  2.50        16.8        113     3.85        3.49
# 4      13.24   2.59  2.87        21.0        118     2.80        2.69
# ..       ...    ...   ...         ...        ...      ...         ...
# 173    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177    14.13   4.10  2.74        24.5         96     2.05        0.76
#
#      Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline  \
# ...

# %% [markdown]
# Kmeans

# %% [markdown]
# Elbow method

# %%
nc=range(1,11)
inertia=[]
for i in nc:
    model_kmean=KMeans(n_clusters=i,random_state=99)
    model_kmean1=model_kmean.fit(wine_transformed)
    inertia.append(model_kmean1.inertia_)
inertia
# Out:
# [95.59953778471063,
#  64.5376670238943,
#  48.960517136676486,
#  44.76933054082477,
#  42.37043092143248,
#  40.19017709677468,
#  38.051907110167384,
#  36.365143377147376,
#  34.3989621544149,
#  33.10632159191673]

# %%
plt.plot(nc,inertia)
plt.scatter(nc,inertia)

# %%
kmean_cluster=KMeans(n_clusters=3,random_state=99)
kmean_cluster1=kmean_cluster.fit_predict(wine_transformed)
kmean_cluster_df=pd.DataFrame(kmean_cluster1,columns=['clusters'])
kmean_cluster_df
# Out:
#      clusters
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ..        ...
# 173         2
# 174         2
# 175         2
# 176         2
# 177         2
#
# [178 rows x 1 columns]

# %%
sns.countplot(x=kmean_cluster_df['clusters'])
# Out:
# <Axes: xlabel='clusters', ylabel='count'>

# %%
kmean_cluster_df.value_counts()
# Out:
# clusters
# 0           62
# 1           61
# 2           55
# dtype: int64

# %%
wine2=wine_info.copy()
wine2['kmean_cluster']=kmean_cluster_df
wine2
# Out:
#      Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0      14.23   1.71  2.43        15.6        127     2.80        3.06
# 1      13.20   1.78  2.14        11.2        100     2.65        2.76
# 2      13.16   2.36  2.67        18.6        101     2.80        3.24
# 3      14.37   1.95  2.50        16.8        113     3.85        3.49
# 4      13.24   2.59  2.87        21.0        118     2.80        2.69
# ..       ...    ...   ...         ...        ...      ...         ...
# 173    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177    14.13   4.10  2.74        24.5         96     2.05        0.76
#
#      Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline  \
# ...

# %%
#both in orginal dataset and k-,ean clustering,number of clusters is 3
#but in heirarchical clustering we found ideal number of cluster as 4
