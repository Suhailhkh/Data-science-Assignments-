# %% [markdown]
# # 2. Salary_hike ---> Build a prediction model for Salary_hike

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pylab as plt
import warnings
warnings.filterwarnings('ignore')
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stat
import pylab

# %%
salary_info = pd.read_csv('Salary_Data (1).csv')
salary_info
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
sns.lmplot(x='YearsExperience', y = 'Salary',data = salary_info)
plt.show()

# %%
model1 = smf.ols(formula='YearsExperience~Salary',data=salary_info).fit()
model1

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        YearsExperience   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Fri, 21 Jul 2023   Prob (F-statistic):           1.14e-20
# Time:                        15:32:35   Log-Likelihood:                -26.168
# No. Observations:                  30   AIC:                             56.34
# Df Residuals:                      28   BIC:                             59.14
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.3832      0.327     -7.281      0.000      -3.054      -1.713
# ...

# %% [markdown]
# # SQRT Transformation

# %%
salary_info['salary_sqrt']=np.sqrt(salary_info['Salary']).round(0)
salary_info
# Out:
#     YearsExperience    Salary  salary_sqrt
# 0               1.1   39343.0        198.0
# 1               1.3   46205.0        215.0
# 2               1.5   37731.0        194.0
# 3               2.0   43525.0        209.0
# 4               2.2   39891.0        200.0
# 5               2.9   56642.0        238.0
# 6               3.0   60150.0        245.0
# 7               3.2   54445.0        233.0
# 8               3.2   64445.0        254.0
# 9               3.7   57189.0        239.0
# 10              3.9   63218.0        251.0
# 11              4.0   55794.0        236.0
# 12              4.0   56957.0        239.0
# 13              4.1   57081.0        239.0
# 14              4.5   61111.0        247.0
# 15              4.9   67938.0        261.0
# 16              5.1   66029.0        257.0
# 17              5.3   83088.0        288.0
# 18              5.9   81363.0        285.0
# 19              6.0   93940.0        306.0
# 20              6.8   91738.0        303.0
# ...

# %%
sns.lmplot(x = 'YearsExperience' , y = 'salary_sqrt' , data = salary_info)
plt.show()

# %%
model2 = smf.ols(formula='YearsExperience~salary_sqrt',data=salary_info).fit()
model2

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        YearsExperience   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.949
# Method:                 Least Squares   F-statistic:                     541.9
# Date:                Fri, 21 Jul 2023   Prob (F-statistic):           7.31e-20
# Time:                        15:45:59   Log-Likelihood:                -28.153
# No. Observations:                  30   AIC:                             60.31
# Df Residuals:                      28   BIC:                             63.11
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -9.8033      0.660    -14.858      0.000     -11.155      -8.452
# ...

# %% [markdown]
# # Log Transformation

# %%
salary_info['salary_log'] = np.log(salary_info['Salary'])

# %%
salary_info
# Out:
#     YearsExperience    Salary  salary_sqrt  salary_log
# 0               1.1   39343.0        198.0   10.580073
# 1               1.3   46205.0        215.0   10.740843
# 2               1.5   37731.0        194.0   10.538237
# 3               2.0   43525.0        209.0   10.681091
# 4               2.2   39891.0        200.0   10.593906
# 5               2.9   56642.0        238.0   10.944506
# 6               3.0   60150.0        245.0   11.004597
# 7               3.2   54445.0        233.0   10.904946
# 8               3.2   64445.0        254.0   11.073567
# 9               3.7   57189.0        239.0   10.954117
# 10              3.9   63218.0        251.0   11.054344
# 11              4.0   55794.0        236.0   10.929422
# 12              4.0   56957.0        239.0   10.950052
# 13              4.1   57081.0        239.0   10.952227
# 14              4.5   61111.0        247.0   11.020447
# 15              4.9   67938.0        261.0   11.126351
# ...

# %%
sns.lmplot(data = salary_info, x = 'YearsExperience' , y = 'salary_log')
plt.show()

# %%
model3 = smf.ols(formula = 'YearsExperience~salary_log', data = salary_info).fit()
model3

# %%
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        YearsExperience   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     383.6
# Date:                Fri, 21 Jul 2023   Prob (F-statistic):           7.03e-18
# Time:                        16:43:45   Log-Likelihood:                -33.035
# No. Observations:                  30   AIC:                             70.07
# Df Residuals:                      28   BIC:                             72.87
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -77.6961      4.241    -18.322      0.000     -86.383     -69.009
# ...
